# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ## Setup

# %%
config = {
    'domain': 'spouse',
    'postgres': False,
    'parallelism': 1,
    'db_name': 'babble_spouse_demo',
    'debug': False,
    'babbler_candidate_split': 1,
    'babbler_label_split': 1,
    'disc_model_search_space': 1,
    'gen_model_search_space': 1,
    'supervision': 'majority_vote',
}

# %%
# Get DB connection string and add to globals
# NOTE: $SNORKELDB must be set before any snorkel imports
import os

default_db_name = 'babble_' + config['domain'] + ('_debug' if config.get('debug', False) else '')
DB_NAME = config.get('db_name', default_db_name)
if 'postgres' in config and config['postgres']:
    DB_TYPE = 'postgres'
else:
    DB_TYPE = 'sqlite'
    DB_NAME += '.db'
DB_ADDR = "localhost:{0}".format(config['db_port']) if 'db_port' in config else ""
os.environ['SNORKELDB'] = '{0}://{1}/{2}'.format(DB_TYPE, DB_ADDR, DB_NAME)
print("$SNORKELDB = {0}".format(os.environ['SNORKELDB']))
# Out:
# $SNORKELDB = sqlite:///babble_spouse_demo.db

# %%
from snorkel import SnorkelSession
session = SnorkelSession()

# Resolve config conflicts (nb_config > local_config > global_config)
from snorkel.contrib.babble.pipelines import merge_configs
config = merge_configs(config)

if config['debug']:
    print("NOTE: --debug=True: modifying parameters...")
    config['max_docs'] = 100
    config['gen_model_search_space'] = 2
    config['disc_model_search_space'] = 2
    config['gen_params_default']['epochs'] = 25
    config['disc_params_default']['n_epochs'] = 5

# %%
from snorkel.models import candidate_subclass
from tutorials.babble.spouse import SpousePipeline

Spouse = candidate_subclass('Spouse', ['person1', 'person2'])
candidate_class = Spouse
pipe = SpousePipeline(session, Spouse, config)

# %% [markdown]
# ## Parse, Extract, Load

# %%
# %time pipe.parse()

# %%
# %time pipe.extract()

# %%
# %time pipe.load_gold()

# %% [markdown]
# ## Now the real work begins...

# %%
from snorkel.contrib.babble import BabbleStream
bs = BabbleStream(session, candidate_class=Spouse, balanced=True, seed=123)

# %%
# from tutorials.babble.spouse.spouse_examples import get_explanations, get_user_lists

# candidates = session.query(Spouse).filter(Spouse.split == 0).all()
# spouse_explanations = get_explanations(candidates)
# spouse_user_lists = get_user_lists()

# %%
# bs.preload(explanations=spouse_explanations, user_lists=spouse_user_lists)

# %%
c = bs.next()

# %%
from snorkel.lf_helpers import *
from IPython.core.display import display, HTML

# %%
chunks = get_text_splits(c)
arg_tmpl = u'<b style="background-color:#ffd77c;padding:1pt 5pt 1pt 5pt;">{0}<small style="color:#4B86A8; font-size:9.5pt;">{1}</small></b>'
sent_tmpl = u'<p style="font-size:12pt;">{}</p>'
div_tmpl = u'''<div style="border: 1px dotted #858585; border-radius:8px;
    background-color:#FDFDFD; padding:5pt 10pt 5pt 10pt">{}</div>'''
text = u""
for s in chunks[0:]:
    if s in [u"{{A}}", u"{{B}}"]:
        span = (c[0].get_span(), " arg1 ") if s == u"{{A}}" else (c[1].get_span(), " arg2 ")
        text += arg_tmpl.format(span[0], span[1])
    else:
        text += s.replace(u"\n", u"<BR/>")
html = div_tmpl.format(sent_tmpl.format(text.strip()))
HTML(html)
# Out:
# <div style="border: 1px dotted #858585; border-radius:8px;
#     background-color:#FDFDFD; padding:5pt 10pt 5pt 10pt"><p style="font-size:12pt;">Personal experience: Cheryl admitted that she couldn't bear to hear the song because the lyrics resonate so strongly with her       Touching moment: <b style="background-color:#ffd77c;padding:1pt 5pt 1pt 5pt;">Sherilyn<small style="color:#4B86A8; font-size:9.5pt;"> arg1 </small></b>'s husband <b style="background-color:#ffd77c;padding:1pt 5pt 1pt 5pt;">Stephen<small style="color:#4B86A8; font-size:9.5pt;"> arg2 </small></b>, who made a full recovery from his accident, was backstage supporting his wife's second chance at a music career       Celebrating: The Welsh songbird's adorable kids couldn't contain their excitement and rushed out onto the stage when she got four yeses from the judges    She explained: ‘</p></div>

# %%
print c[0].get_span()
print c[1].get_span()
# Out:
# Sherilyn
# Stephen

# %%
from snorkel.viewer import SentenceNgramViewer
sv = SentenceNgramViewer([c], session, n_per_page=1, height=200)
sv
# Out:
# A Jupyter Widget

# %%
from snorkel.contrib.babble import Explanation
label = True
condition = "husband is between arg1 and arg2"
explanation = Explanation(condition, label, candidate=c)
explanation
# Out:
# Explanation("True, husband is between arg1 and arg2")

# %%
# %time parse_list, conf_matrix_list, stats_list = bs.apply(explanation)
# Out:
# Created grammar with 494 rules
# 1 explanation(s) out of 1 were parseable.
# 1 parse(s) generated from 1 explanation(s).
# 1 parse(s) remain (0 parse(s) removed by DuplicateSemanticsFilter).
# 1 parse(s) remain (0 parse(s) removed by ConsistencyFilter).
# Applying labeling functions to split 1
# [========================================] 100%
#
# 1 parse(s) remain (0 parse(s) removed by UniformSignatureFilter: (0 None, 0 All)).
# 1 parse(s) remain (0 parse(s) removed by DuplicateSignatureFilter).
# CPU times: user 10.3 s, sys: 2.17 s, total: 12.4 s
# Wall time: 15.7 s

# %%
len(stats_list)
# Out:
# 1

# %%
parse_list[0].semantics
# Out:
# ('.root',
#  ('.label',
#   ('.bool', True),
#   ('.call',
#    ('.in', ('.extract_text', ('.sentence',))),
#    ('.string', 'husband'))))

# %%
conf_matrix_list[0]
# Out:
# ConfusionMatrix(correct=set([Spouse(Span("Danny Moder", sentence=24849, chars=[24,34], words=[4,5]), Span("Julia", sentence=24849, chars=[316,320], words=[64,64])), Spouse(Span("Neil Patrick Harris", sentence=47685, chars=[27,45], words=[7,9]), Span("David Burtka", sentence=47685, chars=[79,90], words=[16,17])), Spouse(Span("Davis", sentence=37356, chars=[13,17], words=[2,2]), Span("Joe", sentence=37356, chars=[62,64], words=[12,12])), Spouse(Span("Jennifer Aniston", sentence=8115, chars=[72,87], words=[13,14]), Span("Justin Theroux", sentence=8115, chars=[101,114], words=[17,18])), Spouse(Span("Kate", sentence=57681, chars=[16,19], words=[4,4]), Span("Jon", sentence=57681, chars=[34,36], words=[7,7])), Spouse(Span("Avril", sentence=52126, chars=[68,72], words=[13,13]), Span("Chad Kroeger", sentence=52126, chars=[95,106], words=[18,19])), Spouse(Span("Simpson", sentence=46386, chars=[0,6], words=[0,0]), Span("O.J. Simpson", sentence=46386, chars=[68,79], words=[15,16])), Spouse(Span("Avril", sentence=52123, chars=[157,161], words=[34,34]), Span("Chad Kroeger", sentence=52123, chars=[230,241], words=[49,50])), Spouse(Span("Baccarin", sentence=38539, chars=[25,32], words=[4,4]), Span("Austin Chick", sentence=38539, chars=[97,108], words=[17,18])), Spouse(Span("Ana Maria", sentence=19902, chars=[315,323], words=[61,62]), Span("Domingo Chavez", sentence=19902, chars=[329,342], words=[64,65])), Spouse(Span("Tracy Leeser", sentence=27400, chars=[0,11], words=[0,1]), Span("Don", sentence=27400, chars=[29,31], words=[5,5])), Spouse(Span("Helen", sentence=42362, chars=[116,120], words=[21,21]), Span("Harry", sentence=42362, chars=[200,204], words=[36,36])), Spouse(Span("Katie Price", sentence=28511, chars=[10,20], words=[2,3]), Span("Kieran Hayler", sentence=28511, chars=[216,228], words=[48,49])), Spouse(Span("Milla", sentence=48884, chars=[112,116], words=[25,25]), Span("Paul Anderson", sentence=48884, chars=[261,273], words=[53,54])), Spouse(Span("Kate", sentence=58355, chars=[0,3], words=[0,0]), Span("Prince William", sentence=58355, chars=[52,65], words=[10,11])), Spouse(Span("Ana Maria Chavez", sentence=19902, chars=[0,15], words=[0,2]), Span("Domingo Chavez", sentence=19902, chars=[53,66], words=[13,14])), Spouse(Span("Milla", sentence=48884, chars=[181,185], words=[38,38]), Span("Paul Anderson", sentence=48884, chars=[261,273], words=[53,54])), Spouse(Span("Dame Helen Mirren", sentence=41716, chars=[0,16], words=[0,2]), Span("Taylor Hackford", sentence=41716, chars=[30,44], words=[5,6])), Spouse(Span("Kim Kardashian", sentence=16303, chars=[352,365], words=[67,68]), Span("Kanye West", sentence=16303, chars=[387,396], words=[72,73])), Spouse(Span("Sherilyn", sentence=54907, chars=[14,21], words=[3,3]), Span("Stephen", sentence=54907, chars=[148,154], words=[34,34])), Spouse(Span("Purvi Joshi", sentence=19877, chars=[12,22], words=[3,4]), Span("Niraj Dave", sentence=19877, chars=[65,74], words=[16,17])), Spouse(Span("Ana Maria", sentence=19906, chars=[263,271], words=[54,55]), Span("Domingo Chavez", sentence=19906, chars=[354,367], words=[71,72])), Spouse(Span("Kim Kardashian", sentence=21199, chars=[0,13], words=[0,1]), Span("Kanye West", sentence=21199, chars=[103,112], words=[16,17])), Spouse(Span(" Bec Hewitt", sentence=62592, chars=[200,210], words=[37,39]), Span("Lleyton", sentence=62592, chars=[316,322], words=[61,61])), Spouse(Span("Domingo", sentence=19906, chars=[12,18], words=[3,3]), Span("Ana Maria", sentence=19906, chars=[263,271], words=[54,55])), Spouse(Span("Milla", sentence=48892, chars=[15,19], words=[3,3]), Span(" Paul Anderson", sentence=48892, chars=[49,62], words=[10,12])), Spouse(Span("Jill Duggar", sentence=36970, chars=[51,61], words=[9,10]), Span("Derick Dillard", sentence=36970, chars=[366,379], words=[73,74])), Spouse(Span("Baccarin", sentence=15321, chars=[40,47], words=[8,8]), Span("Austin Chick", sentence=15321, chars=[69,80], words=[12,13])), Spouse(Span("Cindy", sentence=52784, chars=[43,47], word ...

# %%
print(stats_list[0].accuracy)
print(stats_list[0].class_coverage)
# Out:
# Accuracy: 25.56% (57/223)
# ClassCoverage: 121.86% (223/183)

# %%
from snorkel.viewer import SentenceNgramViewer
error_set = conf_matrix_list[0].correct
sv = SentenceNgramViewer(list(error_set)[:10], session, n_per_page=3, height=300)
sv
# Out:
# A Jupyter Widget

# %%
bs.get_label_matrix()
# Out:
# You must commit before retrieving the label matrix.

# %%
global_coverage = bs.get_global_coverage()
print(global_coverage)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-24-328c61a53039> in <module>()
# ----> 1 global_coverage = bs.get_global_coverage()
#       2 print(global_coverage)
#
# /Users/Stephaniewang/Documents/snorkel/snorkel/contrib/babble/babble.py in get_global_coverage(self)
#     342         TODO: use sparse_abs from snorkel.utils here and elsewhere.
#     343         """
# --> 344         num_labeled = sum(np.asarray(abs(np.sum(self.label_matrix, 1))).ravel() != 0)
#     345
#     346         return GlobalCoverage(num_labeled, self.num_dev_total)
#
# /Users/Stephaniewang/anaconda2/envs/py2Env/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1832             return sum(axis=axis, dtype=dtype, out=out, **kwargs)
#    1833     return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1834                          out=out, **kwargs)
#    1835
#    1836
#
# /Users/Stephaniewang/anaconda2/envs/py2Env/lib/python2.7/site-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# AxisError: axis 1 is out of bounds for array of dimension 0

# %%
bs.commit([0]) # Permanently adds the parses corresponding to these idxs
# Out:
# Added 1 parse(s) to set. (Total # parses = 1)
# Added 1 explanation(s) to set. (Total # explanations = 1)

# %% [markdown]
# Confirm that after committing, global coverage goes up.

# %%
global_coverage = bs.get_global_coverage()
print(global_coverage)
# Out:
# ---------------------------------------------------------------------------
# AxisError                                 Traceback (most recent call last)
# <ipython-input-27-328c61a53039> in <module>()
# ----> 1 global_coverage = bs.get_global_coverage()
#       2 print(global_coverage)
#
# /Users/Stephaniewang/Documents/snorkel/snorkel/contrib/babble/babble.py in get_global_coverage(self)
#     342         TODO: use sparse_abs from snorkel.utils here and elsewhere.
#     343         """
# --> 344         num_labeled = sum(np.asarray(abs(np.sum(self.label_matrix, 1))).ravel() != 0)
#     345
#     346         return GlobalCoverage(num_labeled, self.num_dev_total)
#
# /Users/Stephaniewang/anaconda2/envs/py2Env/lib/python2.7/site-packages/numpy/core/fromnumeric.pyc in sum(a, axis, dtype, out, keepdims)
#    1832             return sum(axis=axis, dtype=dtype, out=out, **kwargs)
#    1833     return _methods._sum(a, axis=axis, dtype=dtype,
# -> 1834                          out=out, **kwargs)
#    1835
#    1836
#
# /Users/Stephaniewang/anaconda2/envs/py2Env/lib/python2.7/site-packages/numpy/core/_methods.pyc in _sum(a, axis, dtype, out, keepdims)
#      30
#      31 def _sum(a, axis=None, dtype=None, out=None, keepdims=False):
# ---> 32     return umr_sum(a, axis, dtype, out, keepdims)
#      33
#      34 def _prod(a, axis=None, dtype=None, out=None, keepdims=False):
#
# AxisError: axis 1 is out of bounds for array of dimension 0

# %%
L_train = bs.get_label_matrix()
L_train

# %% [markdown]
# ### Add another explanation

# %%
from snorkel.contrib.babble import Explanation
label = False
condition = "'where' is within two words to the right of arg 1"
explanation = Explanation(condition, label, candidate=c, name='')

# %%
# %time parse_list, conf_matrix_list, stats_list = bs.apply(explanation)

# %%
print(stats_list[0].accuracy)
print(stats_list[0].class_coverage)

# %%
bs.commit()

# %%
parse = parse_list[0]
parse.semantics

# %%
bs.semparser.grammar.translate(parse.semantics)

# %%
pipe.lfs = [parse.function for parse in bs.parses]
pipe.label()

# %%
# %time pipe.supervise()

# %%
# %time pipe.classify()
