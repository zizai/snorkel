# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

import numpy as np

# %%
config = {
    'project': 'babble',
    'domain': 'protein',
    'db_name': 'babble_protein_goldlabeled',
    'splits': [0,1,2],
    'gold_explanations': True,
}

# %%
# Get DB connection string and add to globals
# NOTE: $SNORKELDB must be set before any snorkel imports
import os

default_db_name = 'babble_' + config['domain'] + ('_debug' if config.get('debug', False) else '')
DB_NAME = config.get('db_name', default_db_name)
if 'postgres' in config and config['postgres']:
    DB_TYPE = 'postgres'
else:
    DB_TYPE = 'sqlite'
    DB_NAME += '.db'
DB_ADDR = "localhost:{0}".format(config['db_port']) if 'db_port' in config else ""
os.environ['SNORKELDB'] = '{0}://{1}/{2}'.format(DB_TYPE, DB_ADDR, DB_NAME)
print("$SNORKELDB = {0}".format(os.environ['SNORKELDB']))
# Out:
# $SNORKELDB = sqlite:///babble_protein_goldlabeled.db

# %%
from snorkel import SnorkelSession
session = SnorkelSession()

# Resolve config conflicts (nb_config > local_config > global_config)
from snorkel.contrib.pipelines import merge_configs, get_local_pipeline
config = merge_configs(config)

from snorkel.models import candidate_subclass
candidate_class = candidate_subclass(config['candidate_name'], config['candidate_entities'])

pipeline = get_local_pipeline(config['domain'])
pipe = pipeline(session, candidate_class, config)
# Out:
# Overwriting domain=None to domain=protein
# Overwriting lr=0.01 to lr=0.001
# Overwriting print_freq=1 to print_freq=5
# Overwriting l2_penalty=1.0 to l2_penalty=0.1
# Overwriting rebalance=0.25 to rebalance=0.5
# Overwriting l1_penalty=1.0 to l1_penalty=0
# Overwriting n_epochs=25 to n_epochs=20
# Overwriting babbler_candidate_split=1 to babbler_candidate_split=[0, 1, 2]
# Overwriting step_size=0.01 to step_size=0.25
# Overwriting reg_param=0.25 to reg_param=0.1
# Overwriting gold_explanations=False to gold_explanations=True
# Overwriting traditional_split=0 to traditional_split=1
# Using ProteinPipeline object.

# %%
# pipe.load_gold()

# %%
pipe.collect()
# Out:
# Linking candidates...
# # CANDIDATES: 7615
# Building list of target candidate ids...
# Collected 29 unique target candidate ids from 30 explanations.
# Gathering desired candidates...
# Found 29/29 desired candidates
# Linking explanations to candidates...
# Linked 30/30 explanations
# Calling babbler...
# Created grammar with 599 rules
# WARNING: Number of candidates (1011) does not equal the number of pos (220) + neg (779) = 999 labels.

# %%
from snorkel.annotations import load_gold_labels, load_label_matrix

TRAIN = 0
DEV = 1
TEST = 2

SPLIT = TEST

L = load_label_matrix(pipe.session, split=SPLIT)
L_gold = load_gold_labels(pipe.session, annotator_name='gold', split=SPLIT)
gold = np.array(L_gold.todense().T)[0]
candidates = [L.get_candidate(pipe.session, i) for i in range(L.shape[0])]

orig_accs = np.array(L.lf_stats(pipe.session, labels=L_gold)['Empirical Acc.'])
orig_lfs = [pipe.babbler.semparser.grammar.translate(exp.semantics) for exp in pipe.explanations]
# Out:
# /Users/bradenjh/repos/snorkel/snorkel/annotations.py:129: RuntimeWarning: invalid value encountered in divide
#   ac = (tp+tn).astype(float) / (tp+tn+fp+fn)

# %%
FILE = 'no_string_{}_lfs.npy'.format(config['domain'])
perts_all = np.load(os.environ['SNORKELHOME'] + '/tutorials/babble/' + config['domain'] + '/data/' + FILE)

# %%
from collections import namedtuple

ParseMock = namedtuple('ParseMock', ['semantics'])

# %%
pert_wins = 0
pert_lose = 0

total_better = 0
total_worse = 0
total_failed = 0
    
garbage = []
    
for i, (orig_lf, orig_acc, perts_list) in enumerate(zip(orig_lfs, orig_accs, perts_all)):
    print("\nLF #{}".format(i))
    print("Original LF: {}".format(orig_lf))
    print("Original Acc: {}".format(orig_acc))
    better = 0
    worse = 0
    failed = 0
    for pert in perts_list:
        sem = eval(pert)
        try:
            lf = pipe.babbler.semparser.grammar.evaluate(ParseMock(sem))
            sig = [lf(c) for c in candidates]
            
            prod = np.multiply(sig, gold)
            agree = sum(prod == 1)
            disag = sum(prod == -1)
            acc = float(agree)/(agree+disag)
            
            if acc > orig_acc:
                print("Better Acc: {}".format(acc))
                better += 1
                print("Better LF: {}".format(pipe.babbler.semparser.grammar.translate(sem)))
            else:
                worse += 1
        except:
            failed += 1
            garbage.append(sem)
        if better:
            break
            
    if better:
        pert_wins += 1
    else:
        pert_lose += 1
        
    total_better += better
    total_worse += worse
    total_failed += failed
        
print("Summary:")
print("Pert Wins: {}".format(pert_wins))
print("Pert Lose: {}".format(pert_lose))

print("Total Better: {}".format(total_better))
print("Total Worse : {}".format(total_worse))
print("Total Failed: {}".format(total_failed))
# Out:
# LF #0
# Original LF: return 1 if (any([s.in(text(between([X,Y]))) for s in user_list('prep')]) and (not any([s.in(text(between([X,Y]))) for s in user_list('negative')]) and count(between([X,Y])).(< 10))) else 0
# Original Acc: 0.485436893204
#
# LF #1
# Original LF: return -1 if any([s.in(text(the sentence)) for s in user_list('nucleic_acids')]) else 0
# Original Acc: 0.955882352941
#
# LF #2
# Original LF: return 1 if ('activ'.in(text(between([X,Y]))) and 'activ'.(all([in(text(within 40 chars of X)),in(text(within 40 chars of Y))]))) else 0
# Original Acc: 0.134615384615
# Better Acc: 0.161290322581
# Better LF: return 1 if ('activ'.in(text(between([X,Y]))) and 'activ'.(all([in(text(within 30 chars of X)),in(text(within 30 chars of Y))]))) else 0
#
# LF #3
# Original LF: return 1 if (text(the sentence).contains('activates') and text(X).in(text(less than 6 word(s) to the right of Y))) else 0
# Original Acc: 0.75
# Better Acc: 1.0
# Better LF: return 1 if (text(the sentence).contains('activates') and text(X).in(text(exactly 6 word(s) to the right of Y))) else 0
#
# LF #4
# Original LF: return -1 if all([s.in(text(the sentence)) for s in ['associat','with']]) else 0
# Original Acc: 0.710144927536
# Better Acc: 0.739361702128
# Better LF: return -1 if any([s.in(text(the sentence)) for s in ['associat','with']]) else 0
#
# LF #5
# Original LF: return 1 if ('between'.(any([in(text(no more than 50 chars to the left of X)),in(text(no more than 50 chars to the left of Y))])) and ('and'.(any([in(text(within 40 chars of X)),in(text(within 40 chars of Y))])) and 'and'.in(text(between([X,Y]))))) else 0
# Original Acc: 0.393939393939
# Better Acc: 0.571428571429
# Better LF: return 1 if ('between'.(any([in(text(no more than 10 chars to the left of X)),in(text(no more than 10 chars to the left of Y))])) and ('and'.(any([in(text(within 40 chars of X)),in(text(within 40 chars of Y))])) and 'and'.in(text(between([X,Y]))))) else 0
#
# LF #6
# Original LF: return 1 if (any([s.in(text(between([X,Y]))) for s in user_list('bindmid')]) and not any([s.in(text(the sentence)) for s in user_list('neg_ind')])) else 0
# Original Acc: 0.565217391304
# Better Acc: 0.608695652174
# Better LF: return 1 if (any([s.in(text(greater than 0 word(s) to the right of X)) for s in user_list('bindmid')]) and not any([s.in(text(the sentence)) for s in user_list('neg_ind')])) else 0
#
# LF #7
# Original LF: return 1 if (count(between([X,Y])).(< 6) and (sum([s.in(text(the sentence)) for s in user_list('int_ind')]).(>= 1) and (not any([s.in(text(the sentence)) for s in user_list('negative')]) and (text(Y).in(text(greater than 0 word(s) to the left of X)) and not any([s.(.eq(u) for at least one u in user_list('between')) for s in ['and','or',',']]))))) else 0
# Original Acc: 0.485714285714
# Better Acc: 0.666666666667
# Better LF: return 1 if (count(between([X,Y])).(< 6) and (sum([s.in(text(the sentence)) for s in user_list('int_ind')]).(> 1) and (not any([s.in(text(the sentence)) for s in user_list('negative')]) and (text(Y).in(text(greater than 0 word(s) to the left of X)) and not any([s.(.eq(u) for at least one u in user_list('between')) for s in ['and','or',',']]))))) else 0
#
# LF #8
# Original LF: return -1 if (','.in(text(between([X,Y]))) and ','.(all([in(text(within 30 chars of X)),in(text(within 30 chars of Y))]))) else 0
# Original Acc: 0.828431372549
# Better Acc: 0.865979381443
# Better LF: return -1 if (','.in(text(between([X,Y]))) and ','.(all([in(text(within 10 chars of X)),in(text(within 10 chars of Y))]))) else 0
#
# LF #9
# Original LF: return 1 if ('complex'.(any([in(text(no more than 50 chars to the left of X)),in(text(no more than 50 chars to the left of Y))])) and (count([char(s) between([X,Y])]).(<= 50) and not any([s.(any([in(text(no more than 50 chars to the left of X)),in(text(no more than 50 chars to the left of Y))])) for s in ['not','no']]))) else 0
# Original Acc: 0.333333333333
# Better Acc: 0.666666666667
# Better LF: return 1 if ('complex'.(any([in(text(no more than 20 chars to the left of X)),in(text(no more than 20 chars to the left of Y))])) and (count([char(s) between([X,Y])]).(<= 20) and not any([s.(any([in(text(no more than 20 chars to the left of X)),in(text(no more than 20 chars to the left of Y))])) for s in ['not','no']]))) else 0
#
# LF #10
# Original LF: return 1 if ('complex'.(any([in(text(no more than 50 chars to the right of X)),in(text(no more than 50 chars to the right of Y))])) and (count([char(s) between([X,Y])]).(<= 50) and not any([s.(any([in(text(no more than 50 chars to the left of X)),in(text(no more than 50 chars to the left of Y))])) for s in ['not','no']]))) else 0
# Original Acc: 0.666666666667
# Better Acc: 1.0
# Better LF: return 1 if ('complex'.(any([in(text(no more than 20 chars to the right of X)),in(text(no more than 20 chars to the right of Y))])) and (count([char(s) between([X,Y])]).(<= 20) and not any([s.(any([in(text(no more than 20 chars to the left of X)),in(text(no more than 20 chars to the left of Y))])) for s in ['not','no']]))) else 0
#
# LF #11
# Original LF: return 1 if (tuple([text(Y),text(X)]).in(user_list('known_targets')) and (text(Y).in(text(greater than 0 word(s) to the left of X)) and text(Y).in(text(less than 8 word(s) to the right of X)))) else 0
# Original Acc: nan
#
# LF #12
# Original LF: return -1 if (count([char(s) between([X,Y])]).(> 150) and count([char(s) between([X,Y])]).(< 500)) else 0
# Original Acc: 0.957746478873
# Better Acc: 0.966666666667
# Better LF: return -1 if (count([char(s) between([X,Y])]).(> 160) and count([char(s) between([X,Y])]).(< 600)) else 0
#
# LF #13
# Original LF: return -1 if text(the sentence).contains('induc') else 0
# Original Acc: 0.886956521739
#
# LF #14
# Original LF: return 1 if 'influenc'.(all([in(text(within 100 chars of X)),in(text(within 100 chars of Y))])) else 0
# Original Acc: 0.0
#
# LF #15
# Original LF: return 1 if (text(the sentence).contains('interact') and count(between([X,Y])).(< 8)) else 0
# Original Acc: 0.5625
# Better Acc: 0.62962962963
# Better LF: return 1 if (text(the sentence).contains('interact') and count(between([X,Y])).(< 2)) else 0
#
# LF #16
# Original LF: return 1 if (any([s.in(text(the sentence)) for s in user_list('interaction_indicators')]) and (count([w for w in the word(s) between([X,Y])]).(< 8) and (not any([s.in(text(the sentence)) for s in user_list('neg_ind')]) and not any([s.in(text(the sentence)) for s in ['induc','sequenc','activ']])))) else 0
# Original Acc: 0.518518518519
# Better Acc: 0.666666666667
# Better LF: return 1 if (any([s.in(text(the sentence)) for s in user_list('interaction_indicators')]) and (count([w for w in the word(s) between([X,Y])]).(= 8) and (not any([s.in(text(the sentence)) for s in user_list('neg_ind')]) and not any([s.in(text(the sentence)) for s in ['induc','sequenc','activ']])))) else 0
#
# LF #17
# Original LF: return -1 if 'level'.in(text(the sentence)) else 0
# Original Acc: 0.901098901099
#
# LF #18
# Original LF: return -1 if any([s.in(text(the sentence)) for s in user_list('mutations')]) else 0
# Original Acc: 0.88
#
# LF #19
# Original LF: return -1 if any([s.(all([in(text(within 100 chars of X)),in(text(within 100 chars of Y))])) for s in user_list('negative')]) else 0
# Original Acc: 0.80608365019
# Better Acc: 0.812987012987
# Better LF: return -1 if any([s.(all([in(text(within 200 chars of Y)),in(text(within 200 chars of Y))])) for s in user_list('negative')]) else 0
#
# LF #20
# Original LF: return 1 if (sum([s.in(text(the sentence)) for s in ['phosphorylation','phosphorylate','phosphorylated','phosphorylates']]).(>= 1) and (count(between([X,Y])).(< 8) and not any([s.in(text(the sentence)) for s in user_list('neg_ind')]))) else 0
# Original Acc: 0.512820512821
# Better Acc: 0.818181818182
# Better LF: return 1 if (sum([s.in(text(the sentence)) for s in ['phosphorylation','phosphorylate','phosphorylated','phosphorylates']]).(> 1) and (count(between([X,Y])).(< 8) and not any([s.in(text(the sentence)) for s in user_list('neg_ind')]))) else 0
#
# LF #21
# Original LF: return 1 if (any([s.(all([in(text(within 60 chars of X)),in(text(within 60 chars of Y))])) for s in ['on','in','to']]) and (count([w for w in the word(s) between([X,Y])]).(< 8) and not any([s.in(text(the sentence)) for s in user_list('neg_ind')]))) else 0
# Original Acc: 0.349264705882
# Better Acc: 0.4375
# Better LF: return 1 if (any([s.(all([in(text(within 60 chars of X)),in(text(within 60 chars of Y))])) for s in ['on','in','to']]) and (count([w for w in the word(s) between([X,Y])]).(= 8) and not any([s.in(text(the sentence)) for s in user_list('neg_ind')]))) else 0
#
# LF #22
# Original LF: return 1 if 'regulat'.(all([in(text(within 100 chars of X)),in(text(within 100 chars of Y))])) else 0
# Original Acc: 0.247619047619
# Better Acc: 0.261261261261
# Better LF: return 1 if 'regulat'.(all([in(text(within 111 chars of X)),in(text(within 111 chars of Y))])) else 0
#
# LF #23
# Original LF: return 1 if (any([s.in(text(the sentence)) for s in user_list('residue')]) and (not any([s.in(text(the sentence)) for s in user_list('neg_ind')]) and count([w for w in the word(s) between([X,Y])]).(< 6))) else 0
# Original Acc: 0.333333333333
# Better Acc: 0.5
# Better LF: return 1 if (any([s.in(text(the sentence)) for s in user_list('residue')]) and (not any([s.in(text(the sentence)) for s in user_list('neg_ind')]) and count([w for w in the word(s) between([X,Y])]).(= 6))) else 0
#
# LF #24
# Original LF: return -1 if (text(X).(= 'c-Jun') and text(Y).(= 'JNK1')) else 0
# Original Acc: 1.0
#
# LF #25
# Original LF: return -1 if any([s.in(text(the sentence)) for s in user_list('signexp')]) else 0
# Original Acc: 0.878378378378
#
# LF #26
# Original LF: return 1 if ('substrate'.in(text(between([X,Y]))) and count(between([X,Y])).(< 8)) else 0
# Original Acc: 0.75
# Better Acc: 0.777777777778
# Better LF: return 1 if ('substrate'.in(text(between([X,Y]))) and count(between([X,Y])).(!= 8)) else 0
#
# LF #27
# Original LF: return -1 if 'transfect'.in(text(the sentence)) else 0
# Original Acc: 1.0
#
# LF #28
# Original LF: return -1 if any([s.in(text(the sentence)) for s in user_list('uncertain')]) else 0
# Original Acc: 0.890625
#
# LF #29
# Original LF: return -1 if text(the sentence).contains('sequenc') else 0
# Original Acc: 0.6
# Summary:
# Pert Wins: 18
# Pert Lose: 12
# Total Better: 18
# Total Worse : 235
# Total Failed: 781

# %%
garbage
# Out:
# [('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 0)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 0)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 0)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 0)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 2)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 2)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 20)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 2)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 3)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 3)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 30)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 3)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 4)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 4)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 40)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 4)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 5)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 5)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 50)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 5)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 6)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 6)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 60)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 6)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 7)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 7)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 70)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 7)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 8)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 8)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 80)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 8)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 9)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 9)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 90)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 9)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 10)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 10)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 100)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 10)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 11)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 11)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 110)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 11)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 12)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 12)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 120)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 12)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 13)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 13)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 130)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 13)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 14)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 14)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 140)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 14)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 15)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 15)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 150)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 15)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 16)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 16)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 160)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 16)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 17)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 17)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 170)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 17)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 18)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 18)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 180)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 18)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 19)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 19)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 190)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 19)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 20)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 20)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 200)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 20)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 21)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 21)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 210)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 21)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 1)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 1)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 1)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 3)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 3)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 3)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 4)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 4)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 4)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 5)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 5)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 5)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 6)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 6)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 6)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 7)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 7)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 7)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 8)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 8)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 8)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 9)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 9)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 9)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 10)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 10)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 10)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 11)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 11)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 11)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 12)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 12)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 12)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 13)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 13)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 13)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 14)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 14)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 14)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 15)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 15)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 15)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 16)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 16)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 16)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 17)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 17)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 17)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 18)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 18)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 18)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 19)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 19)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 19)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 20)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 20)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 20)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 21)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 21)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 21)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 22)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 22)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 22)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 0)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 0)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 0)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 0)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 2)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 2)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 20)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 2)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 3)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 3)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 30)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 3)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 4)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 4)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 40)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 4)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 5)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 5)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 50)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 5)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 6)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 6)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 60)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 6)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 7)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 7)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 70)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 7)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 8)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 8)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 80)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 8)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 9)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 9)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 90)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 9)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 10)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 10)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 100)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 10)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 11)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 11)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 110)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 11)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 12)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 12)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 120)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 12)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 13)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 13)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 130)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 13)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 14)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 14)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 140)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 14)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 15)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 15)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 150)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 15)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 16)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 16)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 160)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 16)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 17)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 17)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 170)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 17)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 18)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 18)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 180)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 18)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 19)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 19)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 190)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 19)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 20)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 20)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 200)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 20)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 21)), ('.arg', ('.int', 2)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 21)), ('.arg', ('.int', 2)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 210)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 21)), ('.arg', ('.int', 2)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 1)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 1)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 1)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 3)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 3)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 3)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 4)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 4)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 4)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 5)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 5)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 5)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 6)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 6)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 6)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 7)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 7)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 7)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 8)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 8)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 8)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 9)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 9)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 9)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 10)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 10)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 10)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 11)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 11)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 11)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 12)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 12)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 12)))))))))),
#  ('.root',
#   ('.label',
#    ('.bool', True),
#    ('.and',
#     ('.any',
#      ('.map',
#       ('.in',
#        ('.extract_text',
#         ('.between',
#          ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 13)))))),
#       ('.user_list', ('.string', u'prep')))),
#     ('.and',
#      ('.none',
#       ('.map',
#        ('.in',
#         ('.extract_text',
#          ('.between',
#           ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 13)))))),
#        ('.user_list', ('.string', u'negative')))),
#      ('.call',
#       ('.lt', ('.int', 10)),
#       ('.count',
#        ('.between',
#         ('.list', ('.arg', ('.int', 1)), ('.arg', ('.int', 13)))))))))),
# ...
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 4)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK4')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 5)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK5')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 6)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK6')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 7)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK7')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 8)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK8')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 9)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK9')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 10)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK10')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 11)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK11')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 12)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK12')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 13)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK13')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 14)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK14')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 15)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK15')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 16)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK16')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 17)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK17')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 18)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK18')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 19)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK19')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 20)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK20')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 21)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK21')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 0)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK0')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 2)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK2')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 3)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK3')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 4)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK4')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 5)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK5')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 6)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK6')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 7)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK7')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 8)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK8')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 9)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK9')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 10)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK10')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 11)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK11')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 12)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK12')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 13)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK13')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 14)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK14')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 15)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK15')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 16)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK16')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 17)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK17')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 18)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK18')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 19)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK19')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 20)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK20')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 21)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK21')),
#      ('.arg_to_string', ('.arg', ('.int', 2))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 1))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 3))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 4))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 5))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 6))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 7))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 8))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 9))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 10))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 11))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 12))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 13))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 14))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 15))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 16))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 17))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 18))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 19))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 20))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 21))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.and',
#     ('.call',
#      ('.eq', ('.string', u'c-Jun')),
#      ('.arg_to_string', ('.arg', ('.int', 1)))),
#     ('.call',
#      ('.eq', ('.string', u'JNK1')),
#      ('.arg_to_string', ('.arg', ('.int', 22))))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.all',
#     ('.map',
#      ('.in', ('.extract_text', ('.sentence',))),
#      ('.user_list', ('.string', u'signexp')))))),
#  ('.root',
#   ('.label',
#    ('.bool', False),
#    ('.all',
#     ('.map',
#      ('.in', ('.extract_text', ('.sentence',))),
#      ('.user_list', ('.string', u'uncertain'))))))]
